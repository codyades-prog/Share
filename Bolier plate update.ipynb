# %%
print('hello world')

# %%
#################################################################################################################################
# About:
## Description: 
## Written by: Josh Butler
## Date of Creation: 
## Frequency of report:
#
# Code reviewed on:
#
# Updates:
##
#################################################################################################################################

## Imports:

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import requests as req
import json
import csv
import datetime as dt
from pprint import pprint
from datetime import date, datetime, timedelta
import time
import math
import re

## Set constants:
save_path = "Save path goes here" ##  include \\ at the end and start with the drive.
### Local creds:
env_path = "H:\\Python\\Secure\\.env" # Update this to whereever your env is located. 
load_dotenv(dotenv_path=env_path)
oauth_client_id = os.getenv('OAUTH_CLIENT_ID')
oauth_client_secret = os.getenv('OAUTH_CLIENT_SECRET')

# %%
# insert csv file where the 'CSV' is#

#with open('CSV', mode='w', newline='') as file:
  #writer = csv.writer(file)
  #writer.writerows(r.json())

# %%
# r = requests.get('https://api.census.gov/data/2020/acs/acs5?get=NAME,B08303_001E,B08303_013E&for=county:*&in=state:36')

# r_json = r.json()

# with open('commute_data.csv', mode='w', newline='') as file:
#   writer = csv.writer(file)
#   writer.writerows(r.json())
